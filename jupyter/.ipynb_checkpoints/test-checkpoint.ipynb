# %%
import requests

# %%
url = 'https://gupiao.baidu.com/stock/sz000877.html'

# %%
r = requests.get(url)

# %%
print(r.encoding)

# %%
r.raise_for_status()

# %%
print(r.encoding)

# %%
print(r.apparent_encoding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7d96abdb390> in <module>()
# ----> 1 print(r.apparent_encoding)
#
# NameError: name 'r' is not defined

# %%
a
# Out:
# utf-8

# %%
r.encoding = r.apparent_encoding

# %%
print(type(r.text))

# %%
print(r.text)
# Out:
# <!DOCTYPE HTML>
# <html lang="en-US">
# <head>
#     <meta charset="UTF-8"><meta name="keywords" content="天山股份(000877),天山股份股票,000877,天山股份股票行情,行情趋势,股市通,证券,证券社区,智能选股,大盘,基本面情况,机构面诊断,基本面诊断,技术面诊断"/><meta name="description" content="股市通为您提供天山股份(000877)股票的行情走势,五档盘口,逐笔交易等实时行情数据,及天山股份(000877)的新闻资讯,公司公告,研究报告,行业研报,F10资料,行业要闻,资金流分析,机构观点,股吧互动等与天山股份(000877)有关的信息和服务"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /><meta name="baidu-site-verification" content="bAUyTfJ5bY" /><meta name="referrer" content="always"/><title>天山股份(000877)个股数据查询 - 个股行情 - 股市通</title><script type="text/javascript">window.alogObjectConfig = {product: '655',page: "655_9",sample: '0.5',speed: {sample: '0.5'},monkey: {sample: '0.5'},exception: {sample: '0.5'},feature: {sample: '0.1'},cus: {sample: '1'},csp: {sample: '0.5','default-src': [{match: '*bae.baidu.com', target: 'Accept,Warn'},{match: '*.baidu.com,*.bdstatic.com,*.bdimg.com,localhost', target: 'Accept'},{match: /^(127|172|192|10)(\.\d+){3}$/, target: 'Accept'},{match: '*', target: 'Accept,Warn'}]}};</script><script type="text/javascript">void function(e,o,t,n,a,i,c){if(e.alogObjectName=a,e[a]=e[a]||function(){(e[a].q=e[a].q||[]).push(arguments)},e[a].l=e[a].l||+new Date,"https:"===e.location.protocol){if(n="https://gss2.bdstatic.com/70cFsjip0QIZ8tyhnq"+n,!e.alogObjectConfig||!e.alogObjectConfig.sample)return}else n="http://img.baidu.com"+n;var g=!0;if(e.alogObjectConfig&&e.alogObjectConfig.sample){var s=Math.random();e.alogObjectConfig.rand=s,s>e.alogObjectConfig.sample&&(g=!1)}g&&(i=o.createElement(t),i.async=!0,i.src=n,c=o.getElementsByTagName(t)[0],c.parentNode.insertBefore(i,c))}(window,document,"script","/hunter/alog/alog.min.js","alog"),void function(){function e(){}window.PDC={mark:function(e,o){alog("speed.set",e,o||+new Date),alog.fire&&alog.fire("mark")},init:function(e){alog("speed.set","options",e)},view_start:e,tti:e,page_ready:e}}(),void function(e){var o=!1;e.onerror=function(e,t,n,a){var i=!0;return!t&&/^script error/i.test(e)&&(o?i=!1:o=!0),i&&alog("exception.send","exception",{msg:e,js:t,ln:n,col:a}),!1},alog("exception.on","catch",function(e){alog("exception.send","exception",{msg:e.msg,js:e.path,ln:e.ln,method:e.method,flag:"catch"})})}(window);</script><link href="/favicon.ico" type="image/x-icon" rel="icon"><link href="/favicon.ico" type="image/x-icon" rel="shortcut icon"><script type="text/javascript"  data-fixed="true">var __gupiao = window.__gupiao || {};var _hmt = _hmt || [];var require = {};require.resourceMap = function(obj) {__gupiao.sourceMap = obj;}</script>
#             <link type="text/css" rel="stylesheet" href="/frontstatic/app/pc/static/css/stock/stock_style_8c6268b.css">
# <!--[if lt IE 9]>
# 	<script type="text/javascript" src="/frontstatic/app/pc/static/js/lib/flashcanvas_dd456f6.js"></script>
# <![endif]-->
#
#
# </head>
# <script> alog('speed.set', 'ht', +new Date);</script>
# <body data-spm="2">
#
# <div id="app-wrap" class="wrap">
#     <!--个股详细页面-->
#     <div class="top-search wrap" data-spm="1">
#     <div class="search">
#         <div class="logo" data-spm="1">
#         <a href="/">
#             <img src="/frontstatic/app/pc/static/img/gst-logo_942ef08.png"/>
#         </a>
#         </div>
#         <div class="search rel">
#             <input type="text" name="q" class="search" placeholder="输入股票名称/代码/首字母" autocomplete="off">
#             <button id='search' class="blue-btn" type="submit" data-spm="2">搜 索</button>
#             <div class="search-div" style="display:none;"></div>
#         </div>
#     </div>
#     <div class="username rel right">
#                 <a id="login-btn" class="login-btn text-highlight" href="https://passport.baidu.com/" data-spm="3">登录</a> |
#         <a class="register-btn" href="//passport.baidu.com/" target="_blank" data-spm="4">注册</a>
#                  |
#         <a class="gst-link text-highlight" target="_blank" href="https://gupiao.baidu.com/download/"  data-spm="5">下载股市通</a> |
#         <a  href="javascript:void(0);" class="add-favorite" data-spm="6" data-track="pc_add_favorite"><i></i>添加到收藏夹</a>
#         <div class="arrow-up app-download" style="display: none;">
#             <img src="/frontstatic/app/pc/static/img/barcode_a75bcca.png" alt="扫码下载股市通app">
#             <div>扫码下载股市通app</div>
#         </div>
#         <input type="hidden" id="stoken-status" value=""/>
#     </div>
# </div>
#
#
# <div class="stock-info" data-spm="2">
#     <div class="stock-bets">
#         <h1>
#             <a class="bets-name" href="/stock/sz000877.html">
#             天山股份 (<span>000877</span>)
#             </a>
#             <span class="state f-up">已休市 2018-09-28 &nbsp;15:00:03
#             </span>
#                     </h1>
#         <div class="price s-up ">
#                         <strong  class="_close">7.92</strong>
#             <span>+0.17</span>
#             <span>+2.19%</span>
#                     </div>
#         <div class="bets-content">
#
#                                             <div class="line1">
#                     <dl><dt>今开</dt><dd class="s-up">7.75</dd></dl>
#                     <dl><dt>成交量</dt><dd>19.90万手</dd></dl>
#                     <dl><dt>最高</dt><dd class="s-up">8.04</dd></dl>
#                     <dl><dt>涨停</dt><dd class="s-up">8.53</dd></dl>
#                     <dl><dt>内盘</dt><dd>8.02万手</dd></dl>
#                     <dl><dt>成交额</dt><dd>1.57亿</dd></dl>
#                     <dl><dt>委比</dt><dd>14.35%</dd></dl>
#                     <dl><dt>流通市值</dt><dd>69.70亿</dd></dl>
#                     <dl><dt class="mt-1">市盈率<sup>MRQ</sup></dt><dd>13.48</dd></dl>
#                     <dl><dt>每股收益</dt><dd>0.29</dd></dl>
#                     <dl><dt>总股本</dt><dd>10.49亿</dd></dl>
#                     <div class="clear"></div>
#                 </div>
#                 <div class="line2">
#                     <dl><dt>昨收</dt><dd>7.75</dd></dl>
#                     <dl><dt>换手率</dt><dd>2.26%</dd></dl>
#                     <dl><dt>最低</dt><dd class="">7.75</dd>
#                     </dl>
#                     <dl><dt>跌停</dt><dd class="s-down">
#                         6.98</dd></dl>
#                     <dl><dt>外盘</dt><dd>11.88万手</dd></dl>
#                     <dl><dt>振幅</dt><dd>3.74%</dd></dl>
#                     <dl><dt>量比</dt><dd>1.22</dd></dl>
#                     <dl><dt>总市值</dt><dd>83.06亿</dd></dl>
#                     <dl><dt>市净率</dt><dd>1.11</dd></dl>
#                     <dl><dt>每股净资产</dt><dd>7.15</dd></dl>
#                     <dl><dt>流通股本</dt><dd>8.80亿</dd></dl>
#                 </div>
#                                         <div class="clear"></div>
#         </div>
#     </div>
#     <ul class="stock-add">
#         <li data-spm="1"><button class="">+ 加自选</button></li>
#         <li class="hint invisible"><span class="add-stock-count">0</span>人关注该股票</li>
#     </ul>
#     </div>
#
#            <div class="f10-menu m-t" data-spm="3">
#     <!-- <a href="/diagnosis/index.html?code=000877" target="_blank" data-spm="1">个股诊断</a> -->
#     <a href="/stock/dzjy/sz000877.html"  target="_blank"  data-spm="2">大宗交易</a>
#     <a href="/stock/lhb/sz000877.html"  target="_blank"  data-spm="3">龙虎榜</a>
#     <a href="/stock/rzrq/sz000877.html"  target="_blank"  data-spm="4">融资融券</a>
#     <a href="/stock/zjlx/sz000877.html"  target="_blank"  data-spm="5">资金流向</a>
#         <a href="http://www.gaf10.com/f10.html?code=000877" target="_blank" data-spm="6">
#     更多F10
#         </a>
#     </div>
#     <!-- 个股页面-左侧 -->
# <div class="left stock-left-box m-t">
# <!-- 五日、分时、周K等数据 -->
#     <div class="timeline-tab" data-spm="4">
#     <ul id="main-chart-tab">
#                 <li class="current" data-tab-index=0 data-spm="1">分时</li>
#         <li class="" data-tab-index=1 data-spm="2">五日</li>
#         <li class="" data-tab-index=2 data-spm="3">日K</li>
#         <li class="" data-tab-index=3 data-spm="4">周K</li>
#         <li class="no-border" data-tab-index=4 data-spm="5">月K</li>
#             </ul>
# </div>
# <div class="flash m-t chart" id="main-chart" data-spm="4">
#     <div class="chart-wrapper">
#         <canvas id="d-chart" width="728" height="329"></canvas>
#         <div class="handicap" id="handicap" data-spm="10">
#             <div class="nav">
#                 <ul><li class="current" data-tab-index="0" data-spm="1">五档</li>
#                 <li data-tab-index="1" data-spm="2">明细</li></ul>
#             </div>
#             <div class="tabs">
#                 <table class="five-range">
#                     <tbody></tbody>
#                 </table>
#                 <table class="detail" style="display:none;">
#                     <thead>
#                         <tr><th width="20%">时间</th><th width="35%" style="text-align:right;">成交价</th><th width="35%" colspan="2" style="text-align:right;">成交量</th></tr>
#                     </thead>
#                     <tbody></tbody>
#                 </table>
#             </div>
#         </div>
#         <div class="arc run" id="d-arc">
#             <div class="bg"></div>
#             <div class="point"></div>
#         </div>
#     </div>
#     <div  class="chart-wrapper">
#         <canvas id="f-chart" width="728" height="329"></canvas>
#     </div>
#     <div  class="chart-wrapper">
#         <div class="k-chart-top-bar">
#             <span class="decrease">缩短K线</span>
#             <span class="increase">拉长K线</span>
#             <div class="fq">
#                 <input type="radio" name="fuquan" value="no" checked="checked" text="不复权">不复权
#                 <input type="radio" name="fuquan" value="front" text="前复权">前复权
#             </div>
#         </div>
#         <canvas id="daily-k-chart" width="728" height="329"></canvas>
#         <div class="k-chart-bottom-bar">
#             <ul>
#                 <li data-type="volume" class="current">成交量</li>
#                 <li data-type="macd">MACD</li>
#                 <li data-type="kdj">KDJ</li>
#                 <li data-type="rsi">RSI</li>
#             </ul>
#         </div>
#     </div>
#     <div  class="chart-wrapper">
#         <div class="k-chart-top-bar">
#             <span class="decrease">缩短K线</span>
#             <span class="increase">拉长K线</span>
#             <div class="fq">
#                 <input type="radio" name="fuquan1" value="no" checked="checked" text="不复权">不复权
#                 <input type="radio" name="fuquan1" value="front" text="前复权"/>前复权
#             </div>
#         </div>
#         <canvas id="weekly-k-chart" width="728" height="329"></canvas>
#         <div class="k-chart-bottom-bar">
#             <ul>
#                 <li data-type="volume" class="current">成交量</li>
#                 <li data-type="macd">MACD</li>
#                 <li data-type="kdj">KDJ</li>
#                 <li data-type="rsi">RSI</li>
#             </ul>
#         </div>
#     </div>
#     <div  class="chart-wrapper">
#         <div class="k-chart-top-bar">
#             <span class="decrease">缩短K线</span>
#             <span class="increase">拉长K线</span>
#             <div class="fq">
#                 <input type="radio" name="fuquan2" value="no" checked="checked" text="不复权">不复权
#                 <input type="radio" name="fuquan2" value="front" text="前复权">前复权
#             </div>
#         </div>
#         <canvas id="monthly-k-chart" width="728" height="329"></canvas>
#         <div class="k-chart-bottom-bar">
#             <ul>
#                 <li data-type="volume" class="current">成交量</li>
#                 <li data-type="macd">MACD</li>
#                 <li data-type="kdj">KDJ</li>
#                 <li data-type="rsi">RSI</li>
#             </ul>
#         </div>
#     </div>
# <div style="width: 100%;height: 360px;line-height: 329px;text-align: center;" id="no-data">暂无数据</div>
# </div>
#
#         <!-- <div class="m-t ad-container" data-spm="5">
#     <a href="https://8.baidu.com/fund/info?code=001732" target="_blank" data-spm="1">
#         <img src="/frontstatic/app/pc/static/img/gf_ad_168b662.png" alt="下载股市通抓涨停牛股"/>
#     </a>
# </div>
#  -->
#     	<div class="m-t ad-container" data-spm="5">
#     <a href="https://gupiao.baidu.com/download/" target="_blank" data-spm="1">
#         <img src="https://8.baidu.com/content/tmp/325a85e4196ec70a94471350a28ecff7.jpg" alt="下载股市通抓涨停牛股"/>
#     </a>
# </div>
#
#                 <script type="text/javascript">void function(e,t){for(var n=t.getElementsByTagName("img"),a=+new Date,i=[],o=function(){this.removeEventListener&&this.removeEventListener("load",o,!1),i.push({img:this,time:+new Date})},s=0;s<n.length;s++)!function(){var e=n[s];e.addEventListener?!e.complete&&e.addEventListener("load",o,!1):e.attachEvent&&e.attachEvent("onreadystatechange",function(){"complete"==e.readyState&&o.call(e,o)})}();alog("speed.set",{fsItems:i,fs:a})}(window,document);</script>
#         <div class="stock-related-tab m-t" data-spm="6">
#         <ul class="tab" data-spm="1">
#             <li class="current" data-tab="news" data-spm="1">新闻</li>
#             <li  data-tab="notice" data-spm="2">公告</li>
#                         <li  data-tab="report" data-spm="3">研报</li>
#                         <li  data-tab="comment" class="hide" data-spm="3">评论</li>
#         </ul>
#         <div class="clearfix"></div>
#     </div>
#     <div class="stock-related-list" data-spm="6">
#         <ul data-spm="2">
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/96e10d99f28553de1e3d1908332141c3" data-spm="1">
#         天山股份:核准豁免中国建材的要约收购义务</a></h4>
#         <p class="desc">
#                     天山股份(000877)12月18日晚间公告，12月15日，公司接到控股股东中国中材股份有限公司通知，中国建材股份有限公司（“中国建材”）已收到证监会下发的《关于核准豁免中国建材股份有限公司要约收购新疆天山水泥股份有限公司股份义务的批复》。核准豁免中国建材因国有资产合并而持有公司35.49%股份而应...
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-12-18 19:00</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/487799887e502f6ff5436b8979dae106" data-spm="2">
#         天山股份:中信证券股份有限公司关于公司非公开发行A股股票发行...</a></h4>
#         <p class="desc">
#
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-12-13 10:02</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/b1b63863cb466107fe4a4ce441b7eb0e" data-spm="3">
#         天山股份:关于非公开发行股票申请获得中国证监会发审会审核通过的...</a></h4>
#         <p class="desc">
#                     证券代码：000877 证券简称：天山股份 公告编号：2017-055 号新疆天山水泥股份有限公司关于非公开发行股票申请获得中国证监会发审会审核通过的公告本公司及董事会全体成员保证信息披露的内容真实、准确、完整，没有虚假记载，误导性陈述或重大遗漏。2017年 11 月 13日，中国证券监督管理委员会...
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-11-14 16:02</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/d635ae1ff1ec0865ed92ebefb9b5fd3b" data-spm="4">
#         天山股份:实控人中国建材集团承诺三年内解决同业竞争</a></h4>
#         <p class="desc">
#
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-11-13 10:30</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/SPDR703426" data-spm="5">
#         天山股份：中建材承诺三年内解决同业竞争</a></h4>
#         <p class="desc">
#
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-11-13 10:10</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/31597a519e41ba49ca21a92759a4a7ee" data-spm="6">
#         ...股东名单中扎堆出现基金、社保等身影,包括凌钢股份、天山股份...</a></h4>
#         <p class="desc">
#                     （原标题：公募社保牛散都在疯狂买入 这几只股今年涨了100%）点击查看&gt;&gt;&gt;机构持仓今年的牛股继续获得机构资金的青睐。基金君根据数据统计发现，在近日已披露三季报的上市公司中，九家今年股价表现突出的个股中，前十大流通股股东名单中扎堆出现基金、社保等身影，包括凌钢股份、天山股份和万华科学等翻倍股。今年股...
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-10-19 07:30</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/3cd29d162ae88f48b3febc9a8d7ece0e" data-spm="7">
#         天山股份:三季度旺季业绩优异增持评级</a></h4>
#         <p class="desc">
#                     [摘要]事件2017年10月17日，天山股份发布2017年三季度报，报告期内公司实现营业收入50.33亿元，同比增加36.31%；实现归属于上市公司股东净利润3.14亿元，同比增长7151.34%。简评营收净利大幅增长，公司生产运营稳步向好报告期内，天山股份实现单季营业收入24.36亿元，同比增加4...
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-10-18 11:16</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/SPDR686881" data-spm="8">
#         天山股份最新消息:业绩同比高增长,三季度旺季业绩优异</a></h4>
#         <p class="desc">
#
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-10-18 09:48</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/5547eea2d82a66df81a2ac9881b39bf1" data-spm="9">
#         业绩暴增71倍,天山股份三季报蕴藏另一个重要信号!</a></h4>
#         <p class="desc">
#                     中国财富网讯（刘畅） 天山股份（000877.SZ）17日披露三季报，公司业绩表现十分强劲，净利润暴增逾71倍，成为三季度名副其实的“增长王”。值得注意的是，尽管上一季度还排在前十位的国家社保基金已悄然离场，但公司前十大股东也有多位新进牛散现身，公司二级市场筹码趋于集中。水泥价格上涨 业绩暴增71倍...
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-10-17 21:03</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#             <li class="row">
#         <h4 class="text-ellipsis"><a target="_blank" href="/article/394efcbd164fe354b3961b2831d0751e" data-spm="10">
#         天山股份(截止9月30日)股东人数为144873户环比减少10.53%</a></h4>
#         <p class="desc">
#                     16:46:50 是的。。我们反复思考过之前的策略。。同一个策略里有掺杂，就会导致大家搞不清楚哪些是长线哪些是短线，从而也没法按长线或短线的手法去区别操作，导致短线变长线，长线变短线。。。这次把超短、波段、长线，完全区分开。。希望大家都能找到适合自己的一片天地，我们也争取每一种风格都能做到同类前茅！...
#         </p>
#         <div class="bottom">
#             <ul class="left">
#                             <li>2017-10-17 02:01</li>
#                                         </ul>
#             <div class="clearfix"></div>
#         </div>
#     </li>
#
# </ul>
# 	<div class="_container pager" >
# 		<input type="hidden" value="1" class="_currentPage" max-page="19" link="/stock/sz000877.html?tab=news"/>
# 		<a class="left-btn _prevPage" href="/stock/sz000877.html?tab=news&page=0" style="display:none" data-spm="4">
# 		</a>
#
#
# 									<!-- 1 2 3 ... n -->
# 									<a class="pagenum _pageLink  current "  page="1"  data-spm="3.1"
# 					href="/stock/sz000877.html?tab=news&page=1" >1</a>
# 									<a class="pagenum _pageLink "  page="2"  data-spm="3.2"
# 					href="/stock/sz000877.html?tab=news&page=2" >2</a>
# 									<a class="pagenum _pageLink "  page="3"  data-spm="3.3"
# 					href="/stock/sz000877.html?tab=news&page=3" >3</a>
# 									<a class="pagenum _pageLink "  page="4"  data-spm="3.4"
# 					href="/stock/sz000877.html?tab=news&page=4" >4</a>
# 									<a class="pagenum _pageLink "  page="5"  data-spm="3.5"
# 					href="/stock/sz000877.html?tab=news&page=5" >5</a>
# 								<a class="pagenum">...</a>
# 				<a class="pagenum _pageLink" page="19"  href="/stock/sz000877.html?tab=news&page=19" >19</a>
# 							<a class="right-btn  _nextPage" href="/stock/sz000877.html?tab=news&page=2" data-spm="5">
# 		</a>
#
# 		<span class="text">跳转到</span>
# 		<input class="page-num _pageNum"/>
# 		<a class="page-btn _pageBtn">
# 			<span class="bg" data-spm="6">确定</span>
# 		</a>
#
# 	</div>
#
#
#
#     </div>
# </div>
# <div class="right stock-right-box">
#     <div class="my-stock side-border m-t stock-side" data-spm="7">
#     <h3 class="section-header">股票</h3>
#     <ul class="side-tab my-stock-tab">
#         <li class="active" data-spm="1" data-track="pc_aside_stock_tab_history">历史</li>
#         <li data-spm="2" data-track="pc_aside_stock_tab_hot_stock">热门</li>
#         <li title="点击刷新自选股" data-groupid data-spm="3" data-track="pc_aside_stock_tab_my_stock">
#             <span data-track="pc_aside_my_stock">自选股</span>
#             <em></em>
#         </li>
#     </ul>
#     <div class="choose-group arrow-up"></div>
#     <div class="my-stock-item active history" data-type="history">
#         <table cellspacing="0">
#             <tbody>
#                 <tr><th>股票名称</th><th>最新价</th><th>涨跌幅</th></tr>
#             </tbody>
#         </table>
#         <div class="no-history hide">您还未有浏览记录</div>
#     </div>
#     <div class="my-stock-item" data-type="hotStock"></div>
#     <div class="my-stock-item" data-type="stock">
#         <table cellspacing="0">
#             <tbody>
#                 <tr><th>股票名称</th><th>最新价</th><th>涨跌幅</th></tr>
#             </tbody>
#         </table>
#                 <div class="my-stock-hint" >
#             <button class="login-btn blue-btn" data-spm="4">登录</button>
#             <p>登录后同步您的自选股</p>
#         </div>
#             </div>
# </div>
#             <!-- <div class="fund-recomm side-border m-t " data-spm="20">
#     <h3 class="section-header">热门基金主题</h3>
#     <ul class="fund-side-tab fund-recomm-tab">
#         <li class="active" data-spm="1" data-track="gupiao_fund_tab_change">稳健增长</li>
#         <li data-spm="1" data-track="gupiao_fund_tab_change">反弹先锋</li>
#     </ul>
#     <div class="choose-group arrow-up"></div>
#
#     <div class="fund-recomm-item active" data-type="theme5">
#
#     </div>
#     <div class="fund-recomm-item" data-type="theme4">
#
#     </div>
# </div> -->
#
#                 <div class="side-fund side-border stock-side m-t"  data-spm="8">
#     <h3 class="section-header">资金</h3>
#     <ul class="side-fund-tab">
#         <li class="active" data-spm="1">今日</li>
#         <li data-spm="2">五日</li>
#     </ul>
#     <div class="side-fund-tab-item clear " style="display: block;">
#         <canvas id="fundChart1" style="height: 0px;"></canvas>
#         <div id="fund-chart-hint" class="arrow-up">
#             <div>主力流入</div>
#             <div>1000万元</div>
#             <div>20%</div>
#         </div>
#         <div class="side-fund-today">
#             <dl>
#                 <dt><i class="fund-main-in"></i>主力流入</dt>
#                 <dd class="col2">--</dd>
#                 <dd class="col3">--</dd>
#             </dl>
#             <dl>
#                 <dt><i class="fund-retail-in"></i>散户流入</dt>
#                 <dd class="col2">--</dd>
#                 <dd class="col3">--</dd>
#             </dl>
#             <dl>
#                 <dt><i class="fund-main-out"></i>主力流出</dt>
#                 <dd class="col2">--</dd>
#                 <dd class="col3">--</dd>
#             </dl>
#             <dl>
#                 <dt><i class="fund-retail-out"></i>散户流出</dt>
#                 <dd class="col2">--</dd>
#                 <dd class="col3">--</dd>
#             </dl>
#             <div class="clearfix"></div>
#         </div>
#     </div>
#     <div class="side-fund-tab-item clear">
#         <canvas id="fundChart2"></canvas>
#     </div>
#     <div class="clear"></div>
# </div>
#         <!-- 个股诊断  -->
#
#         <!-- 基本面 right-ad -->
# <div class="stock-side side-border m-t" data-spm="10">
# 	<h3 class="section-header">基本面</h3>
# 	<div class="industry">
# 		<h4>所属行业</h4>
# 		<p></p>
#
# 		<h4>公司概况</h4>
# 		<p></p>
#
# 		<h4 class="rel">业绩同比增长率	<span></span></h4>
# 		<canvas id="stockRatio"></canvas>
#
# 			</div>
# 	</div>
#
#     </div>
# <!-- 个股页面-右侧 -->
#
# <div class="footer">
#     <p>股市有风险，投资需谨慎！</p>
#     <p>投资者依此做出的投资行为风险自担！</p>
#     <p>© 2018 Baidu
#         <span class="footer-notice">
#             <a href="http://www.baidu.com/duty/" target="_blank">使用百度前必读</a>|<a href="/help/disclaimer" target="_blank">股市通免责声明</a>|<a href="https://www.baidu.com/duty/yinsiquan.html" target="_blank">百度隐私权保护声明</a></p>
#         </span>
# </div>
#
# <div class="fixed-sidebar" data-spm="1.15">
#     <a href="/download/" class="sidebar-block appcode" target="_blank" data-spm="1" data-track="pc_appcode"><i></i><i class="pc_publiccode"></i></a>
#     <a href="javascript:void(0)" class="sidebar-block feedback" id="feedback-btn" data-spm="2" data-track="pc_feedback"></a>
#     <a href="javascript:void(0)" class="sidebar-block return-top" data-spm="3" data-track="pc_return_top"></a>
# </div>
#
#
#
# <script type="text/javascript">(function () {function init_feedback() {if (bds && bds.qa && bds.qa.ShortCut && bds.qa.ShortCut.initRightBar) {var fb_options = {product_id: 188,issuePlaceholder: "欢迎提出您在使用过程中遇到的问题或宝贵建议（400字以内），感谢您对股市通的支持。"};bds.qa.ShortCut.initRightBar(fb_options);}}function loadRightBar() {if (window.bds&&window.bds.qa&&window.bds.qa.ShortCut) {init_feedback();} else {}return false;}document.getElementById("feedback-btn").onclick = loadRightBar;})();function loadScript(url, callback, opt) {var script = document.createElement("script");var opt = opt || {};script.type = "text/javascript";if (opt.charset) {script.charset = opt.charset;}if (opt.id) {script.id = opt.id;}if (script.readyState) {script.onreadystatechange = function () {if (script.readyState == "loaded" || script.readyState == "complete") {script.onreadystatechange = null;callback();}};} else {script.onload = function () {callback();};}script.src = url;document.body.appendChild(script);}</script>
#
# <script type="text/javascript" charset="utf-8" src="/frontstatic/app/pc/static/js/lib/lib_55bed3f.js"></script><script type="text/javascript" charset="utf-8" src="/frontstatic/app/pc/static/js/lib/feedback.js"></script><script type="text/javascript" charset="utf-8" src="/frontstatic/app/pc/static/js/pack/comp_23644a3.js"></script><!--[if lt IE 8]><script type="text/javascript" src="/frontstatic/app/pc/static/js/lib/json.js"></script><script type="text/javascript" src="/frontstatic/app/pc/static/js/lib/console.js"></script><![endif]--><!--[if lt IE 9]>
# <script type="text/javascript">
#     (function() {
#         var canvases = document.getElementsByTagName('canvas');
#         for(var i = 0; i < canvases.length; i++) {
#             var canvas = canvases[i];
#             if (typeof FlashCanvas != "undefined") {
#                 FlashCanvas.initElement(canvas);
#             }
#         }
#     })();
# </script>
# <![endif]-->
# <script type="text/javascript" charset="utf-8" src="/frontstatic/app/pc/static/js/pack/chart_8dcff87.js"></script>
# <script type="text/javascript" charset="utf-8" src="/frontstatic/app/pc/static/js/pack/widget_82529f4.js"></script>
# <script type="text/javascript" charset="utf-8" src="/frontstatic/app/pc/static/js/pack/stock_fd81188.js"></script>
# <script type="text/javascript">__gupiao["stockType"] = "0";__gupiao["asset"] = "0";__gupiao["stockStatus"] = "已休市";__gupiao["stockCode"] = "sz000877";__gupiao["stockName"] = "天山股份";__gupiao["trading"] = "";__gupiao["stockExchange"] = "sz";__gupiao["login"] = "0";__gupiao["uname"] = "";__gupiao["jxNav"] = "1";</script><script type="text/javascript" data-fixed="true">require.async("page/stock/index", function(obj) {obj.init();});</script><script type="text/javascript">void function(e,t,n,a,o,r){function c(t){e.attachEvent?e.attachEvent("onload",t,!1):e.addEventListener&&e.addEventListener("load",t)}function i(e,n,a){a=a||15;var o=new Date;o.setTime((new Date).getTime()+1e3*a),t.cookie=e+"="+escape(n)+";path=/;expires="+o.toGMTString()}function s(e){var n=t.cookie.match(new RegExp("(^| )"+e+"=([^;]*)(;|$)"));return null!=n?unescape(n[2]):null}function l(){var e=s("PMS_JT");if(e){i("PMS_JT","",-1);try{e=e.match(/{["']s["']:(\d+),["']r["']:["']([\s\S]+)["']}/),e=e&&e[1]&&e[2]?{s:parseInt(e[1]),r:e[2]}:{}}catch(n){e={}}e.r&&t.referrer.replace(/#.*/,"")!=e.r||alog("speed.set","wt",e.s)}}if(e.alogObjectConfig){var p=e.alogObjectConfig.sample,d=e.alogObjectConfig.rand;if("https:"===e.location.protocol){if(a="https://gss2.bdstatic.com/70cFsjip0QIZ8tyhnq"+a,!p||!d)return}else a="http://img.baidu.com"+a;p&&d&&d>p||(c(function(){alog("speed.set","lt",+new Date),o=t.createElement(n),o.async=!0,o.src=a+"?v="+~(new Date/864e5),r=t.getElementsByTagName(n)[0],r.parentNode.insertBefore(o,r)}),l())}}(window,document,"script","/hunter/alog/dp.min.js");</script><script type="text/javascript">alog('speed.set', 'drt', +new Date);</script></body>
# </html>
#
# <!--20519482760429925386100710-->
# <script> var _trace_page_logid = 2051948276; </script>

# %%
print(r.content)
# Out:
# b'<!DOCTYPE HTML>\n<html lang="en-US">\n<head>\n    <meta charset="UTF-8"><meta name="keywords" content="\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd(000877),\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd\xe8\x82\xa1\xe7\xa5\xa8,000877,\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd\xe8\x82\xa1\xe7\xa5\xa8\xe8\xa1\x8c\xe6\x83\x85,\xe8\xa1\x8c\xe6\x83\x85\xe8\xb6\x8b\xe5\x8a\xbf,\xe8\x82\xa1\xe5\xb8\x82\xe9\x80\x9a,\xe8\xaf\x81\xe5\x88\xb8,\xe8\xaf\x81\xe5\x88\xb8\xe7\xa4\xbe\xe5\x8c\xba,\xe6\x99\xba\xe8\x83\xbd\xe9\x80\x89\xe8\x82\xa1,\xe5\xa4\xa7\xe7\x9b\x98,\xe5\x9f\xba\xe6\x9c\xac\xe9\x9d\xa2\xe6\x83\x85\xe5\x86\xb5,\xe6\x9c\xba\xe6\x9e\x84\xe9\x9d\xa2\xe8\xaf\x8a\xe6\x96\xad,\xe5\x9f\xba\xe6\x9c\xac\xe9\x9d\xa2\xe8\xaf\x8a\xe6\x96\xad,\xe6\x8a\x80\xe6\x9c\xaf\xe9\x9d\xa2\xe8\xaf\x8a\xe6\x96\xad"/><meta name="description" content="\xe8\x82\xa1\xe5\xb8\x82\xe9\x80\x9a\xe4\xb8\xba\xe6\x82\xa8\xe6\x8f\x90\xe4\xbe\x9b\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd(000877)\xe8\x82\xa1\xe7\xa5\xa8\xe7\x9a\x84\xe8\xa1\x8c\xe6\x83\x85\xe8\xb5\xb0\xe5\x8a\xbf,\xe4\xba\x94\xe6\xa1\xa3\xe7\x9b\x98\xe5\x8f\xa3,\xe9\x80\x90\xe7\xac\x94\xe4\xba\xa4\xe6\x98\x93\xe7\xad\x89\xe5\xae\x9e\xe6\x97\xb6\xe8\xa1\x8c\xe6\x83\x85\xe6\x95\xb0\xe6\x8d\xae,\xe5\x8f\x8a\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd(000877)\xe7\x9a\x84\xe6\x96\xb0\xe9\x97\xbb\xe8\xb5\x84\xe8\xae\xaf,\xe5\x85\xac\xe5\x8f\xb8\xe5\x85\xac\xe5\x91\x8a,\xe7\xa0\x94\xe7\xa9\xb6\xe6\x8a\xa5\xe5\x91\x8a,\xe8\xa1\x8c\xe4\xb8\x9a\xe7\xa0\x94\xe6\x8a\xa5,F10\xe8\xb5\x84\xe6\x96\x99,\xe8\xa1\x8c\xe4\xb8\x9a\xe8\xa6\x81\xe9\x97\xbb,\xe8\xb5\x84\xe9\x87\x91\xe6\xb5\x81\xe5\x88\x86\xe6\x9e\x90,\xe6\x9c\xba\xe6\x9e\x84\xe8\xa7\x82\xe7\x82\xb9,\xe8\x82\xa1\xe5\x90\xa7\xe4\xba\x92\xe5\x8a\xa8\xe7\xad\x89\xe4\xb8\x8e\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd(000877)\xe6\x9c\x89\xe5\x85\xb3\xe7\x9a\x84\xe4\xbf\xa1\xe6\x81\xaf\xe5\x92\x8c\xe6\x9c\x8d\xe5\x8a\xa1"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /><meta name="baidu-site-verification" content="bAUyTfJ5bY" /><meta name="referrer" content="always"/><title>\xe5\xa4\xa9\xe5\xb1\xb1\xe8\x82\xa1\xe4\xbb\xbd(000877)\xe4\xb8\xaa\xe8\x82\xa1\xe6\x95\xb0\xe6\x8d\xae\xe6\x9f\xa5\xe8\xaf\xa2 - \xe4\xb8\xaa\xe8\x82\xa1\xe8\xa1\x8c\xe6\x83\x85 - \xe8\x82\xa1\xe5\xb8\x82\xe9\x80\x9a</title><script type="text/javascript">window.alogObjectConfig = {product: \'655\',page: "655_9",sample: \'0.5\',speed: {sample: \'0.5\'},monkey: {sample: \'0.5\'},exception: {sample: \'0.5\'},feature: {sample: \'0.1\'},cus: {sample: \'1\'},csp: {sample: \'0.5\',\'default-src\': [{match: \'*bae.baidu.com\', target: \'Accept,Warn\'},{match: \'*.baidu.com,*.bdstatic.com,*.bdimg.com,localhost\', target: \'Accept\'},{match: /^(127|172|192|10)(\\.\\d+){3}$/, target: \'Accept\'},{match: \'*\', target: \'Accept,Warn\'}]}};</script><script type="text/javascript">void function(e,o,t,n,a,i,c){if(e.alogObjectName=a,e[a]=e[a]||function(){(e[a].q=e[a].q||[]).push(arguments)},e[a].l=e[a].l||+new Date,"https:"===e.location.protocol){if(n="https://gss2.bdstatic.com/70cFsjip0QIZ8tyhnq"+n,!e.alogObjectConfig||!e.alogObjectConfig.sample)return}else n="http://img.baidu.com"+n;var g=!0;if(e.alogObjectConfig&&e.alogObjectConfig.sample){var s=Math.random();e.alogObjectConfig.rand=s,s>e.alogObjectConfig.sample&&(g=!1)}g&&(i=o.createElement(t),i.async=!0,i.src=n,c=o.getElementsByTagName(t)[0],c.parentNode.insertBefore(i,c))}(window,document,"script","/hunter/alog/alog.min.js","alog"),void function(){function e(){}window.PDC={mark:function(e,o){alog("speed.set",e,o||+new Date),alog.fire&&alog.fire("mark")},init:function(e){alog("speed.set","options",e)},view_start:e,tti:e,page_ready:e}}(),void function(e){var o=!1;e.onerror=function(e,t,n,a){var i=!0;return!t&&/^script error/i.test(e)&&(o?i=!1:o=!0),i&&alog("exception.send","exception",{msg:e,js:t,ln:n,col:a}),!1},alog("exception.on","catch",function(e){alog("exception.send","exception",{msg:e.msg,js:e.path,l ...

# %%
print(type(r.content))
# Out:
# <class 'bytes'>

# %%
from PIL import Image

# %%
from io import BytesIO

# %%
url = 'https://imgsa.baidu.com/news/q%3D100/sign=a19a46404790f60302b098470912b370/3c6d55fbb2fb4316463ab00b2da4462309f7d39e.jpg'
r = requests.get(url)
i = Image.open(BytesIO(r.content))

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x305 at 0x7F1DF06155F8>

# %%
print(i)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x305 at 0x7F1DF06155F8>

# %%
with open('temp.jpg', 'wb') as f:
    f.write(r.content)
